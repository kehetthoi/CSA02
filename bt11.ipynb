# %%
import pandas as pd

# %%
df = pd.read_excel('provinces.xlsx', sheet_name='Sheet1')
df
# Out:
#                  Name              Division                   Region    Area  \
# 0    Thành phố Hà Nội  Thành phố Trung ương      Đồng bằng sông Hồng  3358.6
# 1       Tỉnh Hà Giang                  Tỉnh              Đông Bắc Bộ  7929.5
# 2       Tỉnh Cao Bằng                  Tỉnh              Đông Bắc Bộ  6700.3
# 3        Tỉnh Bắc Kạn                  Tỉnh              Đông Bắc Bộ  4860.0
# 4    Tỉnh Tuyên Quang                  Tỉnh              Đông Bắc Bộ  5867.9
# ..                ...                   ...                      ...     ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  Đồng bằng sông Cửu Long  1439.0
# 59     Tỉnh Hậu Giang                  Tỉnh  Đồng bằng sông Cửu Long  1621.7
# 60     Tỉnh Sóc Trăng                  Tỉnh  Đồng bằng sông Cửu Long  3311.9
# 61      Tỉnh Bạc Liêu                  Tỉnh  Đồng bằng sông Cửu Long  2669.0
# 62        Tỉnh Cà Mau                  Tỉnh  Đồng bằng sông Cửu Long  5221.2
#
#     Population
# 0       8093.9
# ...

# %%
df['Density'] = df['Population'] / df['Area']
df
# Out:
#                  Name              Division                   Region    Area  \
# 0    Thành phố Hà Nội  Thành phố Trung ương      Đồng bằng sông Hồng  3358.6
# 1       Tỉnh Hà Giang                  Tỉnh              Đông Bắc Bộ  7929.5
# 2       Tỉnh Cao Bằng                  Tỉnh              Đông Bắc Bộ  6700.3
# 3        Tỉnh Bắc Kạn                  Tỉnh              Đông Bắc Bộ  4860.0
# 4    Tỉnh Tuyên Quang                  Tỉnh              Đông Bắc Bộ  5867.9
# ..                ...                   ...                      ...     ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  Đồng bằng sông Cửu Long  1439.0
# 59     Tỉnh Hậu Giang                  Tỉnh  Đồng bằng sông Cửu Long  1621.7
# 60     Tỉnh Sóc Trăng                  Tỉnh  Đồng bằng sông Cửu Long  3311.9
# 61      Tỉnh Bạc Liêu                  Tỉnh  Đồng bằng sông Cửu Long  2669.0
# 62        Tỉnh Cà Mau                  Tỉnh  Đồng bằng sông Cửu Long  5221.2
#
#     Population   Density
# ...

# %%
dongnhat = df.loc[df["Density"].idxmax()]
dongnhat
# Out:
# Name          Thành phố Hồ Chí Minh
# Division       Thành phố Trung ương
# Region                  Đông Nam Bộ
# Area                         2061.4
# Population                   9038.6
# Density                     4.38469
# Name: 49, dtype: object

# %%
thap = df.loc[df["Density"].idxmin()]
thap
# Out:
# Name          Tỉnh Lai Châu
# Division               Tỉnh
# Region           Tây Bắc Bộ
# Area                 9068.8
# Population            462.6
# Density             0.05101
# Name: 7, dtype: object

# %%
gb = pd.read_excel("coastlines.xls", sheet_name="Sheet1")
print(gb)
# Out:
#                       Name  Coastline
# 0          Tỉnh Quảng Ninh        250
# 1      Thành phố Hải Phòng        125
# 2           Tỉnh Thái Bình         52
# 3            Tỉnh Nam Định         72
# 4           Tỉnh Ninh Bình         16
# 5           Tỉnh Thanh Hóa        102
# 6             Tỉnh Nghệ An         82
# 7             Tỉnh Hà Tĩnh        137
# 8          Tỉnh Quảng Bình        126
# 9           Tỉnh Quảng Trị         75
# 10     Tỉnh Thừa Thiên Huế        120
# 11       Thành phố Đà Nẵng         37
# 12          Tỉnh Quảng Nam        125
# 13         Tỉnh Quảng Ngãi        130
# 14          Tỉnh Bình Định        134
# 15            Tỉnh Phú Yên        182
# 16          Tỉnh Khánh Hòa        370
# 17         Tỉnh Ninh Thuận        105
# 18         Tỉnh Bình Thuận        192
# 19  Tỉnh Bà Rịa - Vũng Tàu         72
# 20   Thành phố Hồ Chí Minh         17
# 21         Tỉnh Tiền Giang         32
# 22            Tỉnh Bến Tre         60
# 23           Tỉnh Trà Vinh         65
# ...

# %%
df2 = pd.read_excel('coastlines.xls')

# %%
df['Coastline'] = df2['Coastline']
df.fillna(0, inplace=True)
df
# Out:
#    Name               Division              Region                    Area    Population  Density   Coastline
# 0    Thành phố Hà Nội  Thành phố Trung ương      Đồng bằng sông Hồng  3358.6  8093.9      2.409903  250.0
# 1       Tỉnh Hà Giang                  Tỉnh              Đông Bắc Bộ  7929.5   858.1      0.108216  125.0
# 2       Tỉnh Cao Bằng                  Tỉnh              Đông Bắc Bộ  6700.3   530.9      0.079235   52.0
# 3        Tỉnh Bắc Kạn                  Tỉnh              Đông Bắc Bộ  4860.0   314.4      0.064691   72.0
# 4    Tỉnh Tuyên Quang                  Tỉnh              Đông Bắc Bộ  5867.9   786.3      0.134000   16.0
# ..                ...                   ...                      ...     ...         ...       ...        ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  Đồng bằng sông Cửu Long  1439.0  1236.0      0.858930    0.0
# 59     Tỉnh Hậu Giang                  Tỉnh  Đồng bằng sông Cửu Long  1621.7   732.2      0.451502    0.0
# ...

# %%
df2 = pd.read_excel('coastlines.xls')

# %%
sheets = ['CHN', 'LAO', 'KHM']
df = pd.DataFrame()
for sheet in sheets:
    temp_df = pd.read_excel('borders.xls', sheet_name=sheet)
    if sheet == 'CHN':
        temp_df['BorderWith'] = 'China'
    elif sheet == 'LAO':
        temp_df['BorderWith'] = 'Laos'
    else:
        temp_df['BorderWith'] = 'Cambodia'
    
    df = pd.concat([df, temp_df], ignore_index=True)
df
# Out:
#    Tên tỉnh        Tên địa phương giáp biên                                                                     Đường biên (km) BorderWith
# 0        Điện Biên                                                                                   Mường Nhé   40                 China
# 1         Lai Châu                                                       Mường Tè, Nậm Nhùn, Sìn Hồ, Phong Thổ  273                 China
# 2          Lào Cai                                        Bát Xát, Lào Cai, Bảo Thắng, Mường Khương, Si Ma Cai  203                 China
# 3         Hà Giang                       Xín Mần, Hoàng Su Phì, Vị Xuyên, Quản Bạ, Yên Minh, Đồng Văn, Mèo Vạc  272                 China
# 4         Cao Bằng  Bảo Lâm, Bảo Lạc, Thông Nông, Hà Quảng, Trà Lĩnh, Trùng Khánh, Hạ Lang, Phục Hòa, Thạch An  333                 China
# 5         Lạng Sơn                                           Tràng Định, Văn Lãng, Cao Lộc, Lộc Bình, Đình Lập  253                 China
# ...
